# %%
import pandas as pd
liver = pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv')

# %% [markdown]
# # Basic Descriptive Stats

# %%
liver = liver.groupby('Dataset')

# %%
liver.describe().stack(level=0)
# Out:
# /var/folders/74/hypts3796c14nsjcjcxd78hc0000gn/T/ipykernel_39857/1112517625.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   liver.describe().stack(level=0)
#                                     count        mean         std    min  \
# Dataset
# 1       Age                         416.0   46.153846   15.654412   7.00
#         Alamine_Aminotransferase    416.0   99.605769  212.768472  12.00
#         Albumin                     416.0    3.060577    0.786595   0.90
#         Albumin_and_Globulin_Ratio  414.0    0.914179    0.326153   0.30
#         Alkaline_Phosphotase        416.0  319.007212  268.307911  63.00
#         Aspartate_Aminotransferase  416.0  137.699519  337.389980  11.00
#         Direct_Bilirubin            416.0    1.923558    3.206901   0.10
# ...

# %% [markdown]
# # Using a PairPlot

# %%
import seaborn as sns

# %%
sns.pairplot(pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv'))

# %% [markdown]
# # Using pandas_profiling

# %%
# !pip install ydata_profiling
# !pip install ipywidgets
# Out:
# ERROR: Ignored the following versions that require a different python version: 4.0.0 Requires-Python >=3.7, <3.11; 4.1.0 Requires-Python >=3.7, <3.12; 4.1.1 Requires-Python >=3.7, <3.12; 4.1.2 Requires-Python >=3.7, <3.12; 4.10.0 Requires-Python <3.13,>=3.7; 4.11.0 Requires-Python <3.13,>=3.7; 4.12.0 Requires-Python <3.13,>=3.7; 4.2.0 Requires-Python >=3.7, <3.12; 4.3.0 Requires-Python >=3.7, <3.12; 4.3.1 Requires-Python >=3.7, <3.12; 4.3.2 Requires-Python >=3.7, <3.12; 4.4.0 Requires-Python >=3.7, <3.12; 4.5.0 Requires-Python >=3.7, <3.12; 4.5.1 Requires-Python >=3.7, <3.12; 4.6.0 Requires-Python >=3.7, <3.12; 4.6.1 Requires-Python >=3.7, <3.12; 4.6.2 Requires-Python >=3.7, <3.12; 4.6.3 Requires-Python >=3.7, <3.12; 4.6.4 Requires-Python >=3.7, <3.12; 4.6.5 Requires-Python >=3.7, <3.12; 4.7.0 Requires-Python >=3.7, <3.13; 4.8.3 Requires-Python <3.13,>=3.7; 4.9.0 Requires-Python <3.13,>=3.7
# ...

# %%
import ydata_profiling
liver = pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 import ydata_profiling
#       2 liver = pd.read_csv('https://hds5210-data.s3.amazonaws.com/indian_liver_patient.csv')
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
ydata_profiling.ProfileReport(liver, html={'style':{'full_width':True}})
